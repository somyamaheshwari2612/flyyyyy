# %% [markdown]
# <a href="https://colab.research.google.com/github/somyamaheshwari2612/flyyyyy/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/somyamaheshwari2612/flyyyyy/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (Classification)
#
# Task Type: Classification used for Ranking / Scoring.
#
# While the core ML mechanism will likely be a binary classification model (predicting whether a page is declining or not), the ultimate goal of the system is Ranking. We are generating a probability score for each page so we can sort them from highest risk/opportunity to lowest. This ranked queue is what the human reviewers will actually use.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# Target / Proxy: Our proxy label for "needs review" will be a page's decline status. Specifically, we will predict is_declining, which is derived from the observed outcome trend_direction == "down". This proxy assumes that pages actively losing traffic or visibility are the strongest candidates for editorial intervention.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success Metric: Precision@K (e.g., Precision@50)
#
# Generic accuracy does not align with the real-world use case, which is constrained by human editorial capacity. If the team only has time to review 50 pages this week, what matters is how many of the top 50 recommendations were actually true declining opportunities. Therefore, Precision@50 is the metric that proves the model's actual business value.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# Unit of Analysis: One row = one pseudonymized content item (or page).
# The code below loads the starter slice and maps out the target proxy column (is_declining_label) so the ML task has a clear binary target.

# %%
import pandas as pd

#Loading the starter dataset directly from the web (Because this gave an error last time as well)
csv_url = 'https://raw.githubusercontent.com/somyamaheshwari2612/flyyyyy/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(csv_url)

#Sketching the target column: 1 if declining, 0 otherwise
df['is_declining_label'] = (df['trend_direction'] == 'down').astype(int)

#Filtering for a cleaner view of the relevant columns
display_cols = ['content_id', 'impressions_90d', 'sessions_90d', 'content_age_days', 'trend_direction', 'is_declining_label']

#Displaying the unit of analysis (one row = one content page)
df[display_cols].head()
# Out:
#              content_id  impressions_90d  sessions_90d  content_age_days  \
# 0  content_304f48230142             3803            17               187
# 1  content_a1fb4e703a9e            15320             9               445
# 2  content_9aa793d4d895            12581            11               141
# 3  content_331d6c4de07b            11751            78               463
# 4  content_d99b7a2d90ca            19140           145               263
#
#   trend_direction  is_declining_label
# 0            down                   1
# 1            down                   1
# 2            down                   1
# 3          stable                   0
# 4            down                   1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
# A fixed rule (e.g., if age > 180 and impressions_90d > 500 and trend == "down") is brittle. It forces us to guess the perfect arbitrary thresholds. ML can weigh dozens of continuous signals simultaneously,such as the exact interplay between a page's age, its CTR gap, and its engagement rate; finding non-linear patterns and subtle decay risks that a hardcoded if-statement would completely miss.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
